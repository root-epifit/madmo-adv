# %% [markdown]
# <a href="https://colab.research.google.com/github/root-epifit/madmo-adv/blob/my_exercise/text-generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Char-based text generation with LSTM

# %%
from collections import Counter

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %%
TRAIN_TEXT_FILE_PATH = 'train_text.txt'

with open(TRAIN_TEXT_FILE_PATH) as text_file:
    text_sample = text_file.readlines()
text_sample = ' '.join(text_sample)

def text_to_seq(text_sample):
    char_counts = Counter(text_sample)
    char_counts = sorted(char_counts.items(), key = lambda x: x[1], reverse=True)

    sorted_chars = [char for char, _ in char_counts]
    print(sorted_chars)
    char_to_idx = {char: index for index, char in enumerate(sorted_chars)}
    idx_to_char = {v: k for k, v in char_to_idx.items()}
    sequence = np.array([char_to_idx[char] for char in text_sample])
    
    return sequence, char_to_idx, idx_to_char

sequence, char_to_idx, idx_to_char = text_to_seq(text_sample)
# Out:
# [' ', 'о', 'е', 'а', 'н', '\n', 'т', 'и', 'л', 'с', 'р', 'в', 'д', 'м', ',', 'у', 'к', 'ь', 'ы', 'й', 'п', 'я', 'г', 'б', 'з', 'ч', 'ж', 'х', '.', 'ш', 'ю', 'И', ';', 'Н', 'X', 'В', 'I', 'П', 'О', 'ц', 'Т', 'С', 'К', ':', '!', 'Д', '?', 'щ', 'Б', 'Е', 'V', 'М', 'У', '…', 'Ч', 'З', 'Л', 'э', 'Г', '«', '»', '–', 'Я', '-', 'А', 'ё', '—', 'L', 'Р', 'ф', 'e', 'Х', ')', '(', 't', 'a', 'ъ', 'Ж', 'l', 'o', 'r', 'n', 'Ш', 'i', 'Ф', 's', 'u', 'd', 'm', 'Ц', 'b', 'c', 'Э', 'v', 'M', '€', 'N', 'A', 'f', 'S', '7', 'Ю', 'h', 'B', 'P', 'p', '[', ']', '’', 'T', 'k', 'z', 'g', '^', 'y', '5', 'C', 'H', 'Y', 'Q', 'q', 'W', 'R', 'G', 'D', '8', '9']

# %%
sequence[:20]
# Out:
# array([36,  5,  0,  5,  0,  0,  0, 59, 51,  1, 19,  0, 12, 21, 12, 21,  0,
#         9,  3, 13])

# %%
SEQ_LEN = 256
BATCH_SIZE = 16

def get_batch(sequence):
    trains = []
    targets = []
    for _ in range(BATCH_SIZE):
        batch_start = np.random.randint(0, len(sequence) - SEQ_LEN)
        chunk = sequence[batch_start: batch_start + SEQ_LEN]
        train = torch.LongTensor(chunk[:-1]).view(-1, 1)
        target = torch.LongTensor(chunk[1:]).view(-1, 1)
        trains.append(train)
        targets.append(target)
    return torch.stack(trains, dim=0), torch.stack(targets, dim=0)

# %%
def evaluate(model, char_to_idx, idx_to_char, start_text=' ', prediction_len=200, temp=0.3):
    hidden = model.init_hidden()
    idx_input = [char_to_idx[char] for char in start_text]
    train = torch.LongTensor(idx_input).view(-1, 1, 1).to(device)
    predicted_text = start_text
    
    _, hidden = model(train, hidden)
        
    inp = train[-1].view(-1, 1, 1)
    
    for i in range(prediction_len):
        output, hidden = model(inp.to(device), hidden)
        output_logits = output.cpu().data.view(-1)
        p_next = F.softmax(output_logits / temp, dim=-1).detach().cpu().data.numpy()        
        top_index = np.random.choice(len(char_to_idx), p=p_next)
        inp = torch.LongTensor([top_index]).view(-1, 1, 1).to(device)
        predicted_char = idx_to_char[top_index]
        predicted_text += predicted_char
    
    return predicted_text

# %%
class TextRNN(nn.Module):
    
    def __init__(self, input_size, hidden_size, embedding_size, n_layers=1):
        super(TextRNN, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.embedding_size = embedding_size
        self.n_layers = n_layers

        self.encoder = nn.Embedding(self.input_size, self.embedding_size)
        self.lstm = nn.LSTM(self.embedding_size, self.hidden_size, self.n_layers)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(self.hidden_size, self.input_size)
        
    def forward(self, x, hidden):
        x = self.encoder(x).squeeze(2)
        out, (ht1, ct1) = self.lstm(x, hidden)
        out = self.dropout(out)
        x = self.fc(out)
        return x, (ht1, ct1)
    
    def init_hidden(self, batch_size=1):
        return (torch.zeros(self.n_layers, batch_size, self.hidden_size, requires_grad=True).to(device),
               torch.zeros(self.n_layers, batch_size, self.hidden_size, requires_grad=True).to(device))

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model = TextRNN(input_size=len(idx_to_char), hidden_size=128, embedding_size=128, n_layers=2)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2, amsgrad=True)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, 
    patience=5, 
    verbose=True, 
    factor=0.5
)

n_epochs = 5000            # 50000
loss_avg = []

for epoch in range(n_epochs):
    model.train()
    train, target = get_batch(sequence)
    train = train.permute(1, 0, 2).to(device)
    target = target.permute(1, 0, 2).to(device)
    hidden = model.init_hidden(BATCH_SIZE)

    output, hidden = model(train, hidden)
    loss = criterion(output.permute(1, 2, 0), target.squeeze(-1).permute(1, 0))
    
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    
    loss_avg.append(loss.item())
    if len(loss_avg) >= 50:
        mean_loss = np.mean(loss_avg)
        print(f'Loss: {mean_loss}')
        scheduler.step(mean_loss)
        loss_avg = []
        model.eval()
        predicted_text = evaluate(model, char_to_idx, idx_to_char)
        #print(predicted_text)
# Out:
# Loss: 3.0130217981338503
#   оне слолоте,
#    Оа но век овей вол вел велов но стово волом но волель ситет сеть вело слево воте но вел но но сет во сет вен вут осно но вот оне сей но та витоге бата  отел вето но воги но селом ен в
# Loss: 2.3970568132400514
#  Он седень,
#    Но на додоль нони в поровий нась,
#    И в не не в в вал накодоль стого достать оненье тора столь оми сторы столь
#    На тополь столь сторень вавасто не поренья сторей
#    В порего порать по
# Loss: 2.212592353820801
#  Прадать додной веренье
#    И сториль сердей,
#    И в порать стом он пововет,
#    Ей не поволь вать вась вас вавной,
#    Не поволь сторой сенет,
#    Не пороченевит поли,
#    И полкой поленье мора
#    Дорил не
# Loss: 2.0953247213363646
#  Пороженный не не своей не подой
#    И на столь в подором он он он сторей
#    Покой на в породать со в не стольной
#    Постом пора не годой нам,
#    И породно столить сторой
#    Но постала постовь сельный,
#
# Loss: 2.0030565643310547
#   И столете не на нам
#    И год он совенья моей.
#    И стольно в на сладит,
#    В страдет сердца в ленит долодой
#    И не вор вордать порой
#    В порельный сторого всегда,
#    Прогольно женный следный подоль
# Loss: 1.9326809597015382
#   Столно в садет в не своей,
#    Когда был медь не в негина,
#    Как не странить он сердце в темно
#    Стредно стредно на сердца,
#    Но не страдно стременьей странный,
#    Как и страть сердце в не и своей
#
# Loss: 1.8837608003616333
#   Но сомно сомнал семья
#    Но и соседь странил самился,
#    И приновь подоворованье,
#    Но старина сольно странить
#    Как сам и сомной доменья,
#    Но в пора соверь он сам она
#    И полкой слова нас и пос
# Loss: 1.8404370546340942
#   Как на стара старой,
#    И страстал на был не страны,
#    И постала породный своей
#    И странил он подолодной всё сердце,
#    В долго на друг она славит,
#    Под постолодной в нас она
#    И в постет и мое
# Loss: 1.803317527770996
#   С недвуженный летельный,
#    Не постал он столит в судит,
#    На страсти поверный порой.
#    С оставил он не слажит,
#    На страсти приласти славы,
#    И видет она страсти свете,
#    И воскова в слез умени
# Loss: 1.7759892344474792
#   Не востель должна не востанье
#    Вот полной сердце городной
#    Так в поставил и не не своей,
#    И в своей страсти полной своей
#    Когда то полно привогда,
#    В неворой слезам поставилась.
#    Но в нем
# Loss: 1.747479453086853
#   Стородной порой сердцем
#    С долго был верно в ней он в томный,
#    Он постором на старине
#    Что в ней сердцем полова подота
#    Не восподновенный домой,
#    И в нем не страсти подавленье
#    И в полно
# Loss: 1.7200237703323364
#   Она волненный сердце воле,
#    И в нем она в сердце светом
#    И стралит и володной страсти,
#    В он на страсти сердца слезами
#    И на вереди солнце,
#    В волна привычный весель старин,
#    Она мире мол
# Loss: 1.6957145786285401
#   И возвет страстной долго подам
#    И в сомненный словая подам,
#    Но в похнет в гости в не стрательной
#    И в сердце слова в сумой полно
#    И столо слова странилась
#    Простой посторой полодной
#    Сво
# Loss: 1.6749350309371949
#  Не воскружен обновенный,
#    И всё велик с ней постеле
#    В свет писала подолодой,
#    Всё старом с волного в ней постели
#    Всё страшной вод воскрасной нет
#    С оставили на своей столе
#    И в послушал
# Loss: 1.651937689781189
#   И верна сердцем сердце странной
#    И верный волна, то долго,
#    И верных был в нем поверенье
#    И в поставенный поставал
#    И мечтанье столовенный,
#    И не старины поленый,
#    Под не старины страстны
# Loss: 1.641810779571533
#   Весны скоро страшной старом
#    И не страшно стройной стором
#    И привечно в сомнений стал,
#    И страшно толки полно странит
#    И в своей полный предота.
#    Но в полно помненный странит,
#    Всегда стр
# Loss: 1.6256819367408752
#   В сам не странный судьбом судьбом,
#    И в том наш постель ее дев,
#    Под ней не страшний просторов,
#    В дома слов и все дней молодой
#    Простовый сердца без верной
#    И долго ей в самой небреда
#    В
# Loss: 1.6045317983627319
#   Свои старинной меня постал
#    И после в стол на приятный,
#    И в сердца страстной веселый,
#    Старотно в ней страшно не след,
#    И пропыл и постолка и странит,
#    И забыть не поскала след,
#    Постой
# Loss: 1.5958862686157227
#   Придета своего садой
#    Старой под подовалась на доле
#    И в сердца странное полной
#    И в нем оставил на света,
#    Не простот души ль полна нет.
#    И странно в подоровал, —
#    Вот проводит на своего
# Loss: 1.5900477695465087
#   В полно в сердце с нас возврать он нет.
#    Всё дам подругой старою слезы
#    И в как друг и слова света,
#    И сердце соседственный странный,
#    И в то странен в нем и сердцем
#    И в собой по в ней под
# Loss: 1.5649724435806274
#   В помнить не странит и верной,
#    В деревне страсти в нем обода
#    И не молча в томный славы,
#    Когда страненный постель может,
#    В нем отворине в ней поданья,
#    С ней странной восторованный,
#    И
# Loss: 1.5633575892448426
#   На старинный порой страсть вам
#    Онегин он полный легка,
#    В том страсть моя в перед он всех
#    И в своей возвратит он нет.
#
#
#
#  XXXIII
#
#    В том слезы простой долго слова,
#    И в сей он одна св
# Loss: 1.5475722575187683
#   Когда в ней полно не приходит,
#    И странной простотой сердце,
#    В долго не стразить не страсти
#    И не сердце подругом нет.
#    Но в нем полной пора не слушать,
#    И в подвестью не терпеть и день
#
# Loss: 1.5413603019714355
#   Как он с ним образливой старинный,
#    На следованный под ней душой
#    Не воспомнений душой сосед
#    И в сердце пред ней своей своей.
#
#
#
#  XXIII
#
#    Но всех не своих полным окно,
#    И всех не страс
# Loss: 1.5330300188064576
#   Он оставлял он под своей страсти
#    Он в сердца пред ней неворей
#    Старинный сердцем и вас,
#    Вот может с ней наш и привык
#    И на старинный беседам,
#    И своих воспомнить он нас;
#    В то простей п
# Loss: 1.5202508926391602
#   И всё приятно своей душа,
#    В ней под ней сердце подобный,
#    Не пора слова полный дев.
#
#
#
#  XXXIII
#
#    Все для верно в ней полной углам,
#    И том полные старины,
#    Подруги подруга постала
#    На
# Loss: 1.5052408719062804
#   Что мог не верный и правда,
#    И в думал он устах полей.
#    Не волненье примете нет
#    Она по признаться силый,
#    В долго в нем оставленье мой
#    Покойных долго в картины,
#    Что ж он весели все был
# Loss: 1.5049871039390563
#   Под полно в ней странный взором,
#    Он сердце гордости не верной
#    И вот улыбки меня мой
#    И вашей не верно в ней верно
#    Как так не полно не ведал
#    И волненье страстью отрада
#    Признаться не н
# Loss: 1.504611485004425
#   И в бедний должен в старом полный странились,
#    И настанит на старой страсти,
#    И старины не полный страницы
#    И в темной как на старины,
#    И волнуется во всех,
#    Где своей приходит соне.
#    Но
# Loss: 1.4889261555671691
#   Прости свои всех привычный,
#    И послушный души месте,
#    И всех старых старины дела,
#    И всех улыбкой трудов она
#    С отором переставилась
#    В сень моей воспоминали,
#    И вот на то всех сердце стр
# Loss: 1.4826187205314636
#   Онегин полной своей полей
#    Свои привыком обедам,
#    И в размете любила красных,
#    Не отстал он подался в ней
#    Под ней после воскреслованье,
#    И старине после своей.
#
#
#
#  XXXII
#
#    Но всех не
# Loss: 1.4811246466636658
#   И всё в ней и пора не вечерней
#    В том самом подался признаньем
#    На старушков подобно своей.
#
#
#
#  XXXIII
#
#    Но старом не видел она.
#    В то ж он в ней на старой полна,
#    Как наш поле весела с
# Loss: 1.4701654601097107
#   С капли в семьем в совершенством
#    И полный и в подруга, как нет
#    И в старины на потом,
#    И поспешит он в перед свет,
#    И в сердце привык и поражет
#    В избы слова на старины
#    И в семья в отст
# Loss: 1.4694586420059204
#   Он всех сердце поставляет собою
#    И он порой и своей своей;
#    Он веселый молодой страницы
#    На порой поставил он в том,
#    В нем с переставили с ней собой,
#    И в сердце в сердце привычный,
#    И п
# Loss: 1.462698712348938
#   На старой старой себя сон.
#
#
#
#  XXXIII
#
#    Но свете старой встречает —
#    И старой дела страстный страсть
#    На старой привез володой
#    С как молодой души предскак,
#    Старый представить его так
#
# Loss: 1.455580494403839
#   Стоел он простотой воловой,
#    Оставить он не полные верно
#    И все постеле братьяна страсть
#    И все пред ней не в соседован
#    Приятный молчаливо странный,
#    И с ней на сердце старинный,
#    И полн
# Loss: 1.4489706993103026
#   Прости в старины полон,
#    Под ней наш соседственный сель
#    И вот на то всех устах даль.
#    Вот улыбкой получины даль
#    Там страшно не волненье мог,
#    В том полно в нем обедам в дома,
#    И полные
# Loss: 1.4398586392402648
#   И в себя на старины, след.
#
#
#
#  XXXIII
#
#    Но в сердце поверился привет.
#
#
#
#  XXXIII
#
#    «Не страсти в темной клеветы,
#    Когда в нем и сердце странной
#    В семье не всё не привету
#    И в себя
# Loss: 1.4372299718856811
#
# Loss: 1.4288362908363341
#   В так на то всех своей полный,
#    И в нем обедать он на света
#    В сем и старинный разговор,
#    В перед подымал он вости,
#    Всегда под сердцем он подокрасный,
#    И наше страшно и страшной,
#    И полн
# Loss: 1.4249870228767394
#   Довольно с ним и домашной друзья,
#    И полной полно не спешит
#    И в самом простой старины,
#    В сем своей после в семья, —
#    Но во мне привыкней странный взор
#    И в ней после в стороны страсть,
#
# Loss: 1.4163420581817627
#   Как верный вздохнет и лесов,
#    И в порок надежды простой
#    И проходит вот в то волненье,
#    Как без вернели в совершенственный,
#    Прости простой веселье след,
#    Не отстал и блестит она,
#    Старин
# Loss: 1.4203627848625182
#   В под ней полуденный день надежда,
#    И в ней собой полный под света
#    Старый солнце под ним сердцем
#    И в нем от уследит подором
#    В сумрачной дом ужасе нет;
#    Она в нем и привычках мой,
#    И кр
# Loss: 1.4090016531944274
#   Своей стары своей помнился,
#    Под ним подругой подымал.
#
#
#
#  XXVIII
#
#    Он в приятно с ней не возвратить,
#    И все построхованы слова
#    В сем возвратительной подруг,
#    Онегин в нем ее своей.
#
# Loss: 1.4112668228149414
#   И страстей был не старины сладкой,
#    Другой не шевельнул она
#    Давно под себе полно не вот
#    На старый подавал восты
#    И верно в ней проходит сон.
#    Он в стол сердце с после слова,
#    И страстей
# Loss: 1.4105152297019958
#   Он весна в мертвец на сона.
#    Всё был веселья на слезы
#    Он верно так и в ней невольно,
#    И в ней и старинных другий,
#    И в сем и всех постеле нет.
#
#
#
#  XXXIII
#
#    Так без в полно в сумраке в
# Loss: 1.3998601341247559
#   В посланье страшно не веселый вздом;
#    Всё беседу простой своей.
#
#
#
#  XXIII
#
#    Но вот ни своей разрешный,
#    И в сем он не постели вы,
#    И вот старинной деревенский,
#    И ветрены пред нем не ви
# Loss: 1.3991199111938477
#   Под ней дом сердце своей взор,
#    И станик он пошли друзья.
#    Он слезами страшно горой,
#    В слез без без умиленья страстей
#    И старый мой полно слезы
#    С первой и стремя старой проды,
#    И всё бы
# Loss: 1.3893594121932984
#   Невольно в ней собой своей подонный,
#    И сердце подобен она.
#    Благословил он полетел
#    Он по сон не волненье верный,
#    И девы молодой и простой
#    И страсти на странный послушный,
#    Стоял конце
# Loss: 1.3944045162200929
#   И в нем не веселья надежда
#    В вод он по крайней мало нет.
#    Он старый годы не могу…
#    Но в темно и сладостный даме
#    И славы не досель оставить
#    И страшно не старела доле.
#
#
#
#  XXXII
#
#    Во
# Loss: 1.3914512848854066
#   Покамест и чем и страсти,
#    И старый пред своей посугам,
#    И свет обновляется постель
#    На сосед от сердце полной,
#    Татьяна сладкой оставить,
#    И простой верный постеле
#    И после в сад и стары
# Loss: 1.37821914434433
#   И на старины не старины
#    И станно так и сладости,
#    И страстей и в семья, в так слезы
#    Прости своей ветвернуть нас
#    Как любовь и старинный мой
#    И стол и без из получила
#    В сосед и сердце с
# Loss: 1.3777486562728882
#  И взор на старинных старины
#    На стал с ним на старинной доле
#    И не старинных сосед сон.
#    В то всех другом стол и последней
#    Приводит по только в нем иной
#    И сердце в нем и с ней досель
#    И
# Loss: 1.3785236358642579
#   И встретил он в картины слеза
#    Так не верно не волнами,
#    И в поле не весела страстей.
#    Но славы не полетый мой
#    И волнами видит она
#    Друга пред ней не привыкновенье
#    И вы не приятно вы со
# Loss: 1.3678702974319459
#   И в деревне пора привычки,
#    В сем и не поскорей полей
#    И постеле на страстной своей
#    Как прости в то в ней не в сани,
#    Как бесколько сладкой обрадой,
#    На старой слезы не полей,
#    Под подав
# Loss: 1.3682951760292053
#   И верно подорно всех молодой
#    Принять водая страшно нет;
#    Но ты молодой беспечной
#    И полевой честной страшно,
#    И вот другом он молчаливо,
#    Не подругой скоро всех друг.
#    Как заменит, как т
# Loss: 1.366546196937561
#   С ней не полно поверьте волненье,
#    И всё страстной подобенах
#    И старины не волненье,
#    И в нем от небес подружалась,
#    И всё в мечтанья полно врасть,
#    И вот на старины не встречно
#    И встреч
# Loss: 1.3616733384132385
#   Он последнем своей душою,
#    И сладостный взор ее слова
#    И полный и скоро в ней ней
#    И с простой старинных слезам
#    Со старинной думать мой луг
#    И в семье в сумраке наших.
#    Все не постель по
# Loss: 1.3694114089012146
#   Покамест и слез и верной
#    В сем и все страстей и привык
#    Он сердце толковать не мог
#    Не долго в старины сердце,
#    И на полны посланье рад,
#    Как не пред ней не из подруг,
#    Не полный взор по
# Loss: 1.3575947284698486
#   Пора не страстной старины.
#    К ней наш не веселить я нет.
#
#
#
#  XXXVIII
#
#    Вот после моего слезы,
#    И всё было не свои деревне
#    Да был не после подруги,
#    Что был подругой своим нет;
#    Вот д
# Loss: 1.353098018169403
#   И всё поэта наслаждает сон,
#    И подобен с ней не раздалый,
#    И полно не старины невет
#    И постеле и страшно нет.
#
#
#
#  XXXII
#
#    Так не в сон приятный вздохов,
#    И на старой постеле небес,
#    И
# Loss: 1.3578708291053772
#   И в поле надежду невольно,
#    И вы приветству после следов,
#    То под бурный томные друзья,
#    И просто полные страстной,
#    И всё страстной старый под девы
#    В ней не страстной страшнит страстей,
#
# Loss: 1.3444176506996155
#   Под ней столь сосед и смертью за страстей.
#
#
#
#  XXXIV
#
#    Но там об ним он в садит сонный,
#    Придет с ним об ней послушной
#    В курок восторгов и своей.
#
#
#
#  XXVII
#
#    Но в нем с ним подругой
# Loss: 1.352378821372986
#   В деревне не слушает подобен
#    И в стороно в первый забывал
#    И вот на старинный сон, как воле
#    Прости был послушный своей.
#    Всё то же старинный долойный,
#    И нет волненье страстный взор
#    И
# Loss: 1.3462499713897704
#   Потом страшно не своей подобен
#    И слезы не привычный странной
#    Старинный мой моей страсти
#    И в сем и страшно примирала
#    С тень моей страшно полный лиры
#    И на бестолковать пора
#    Не полно,
# Loss: 1.3452840662002563
#   И вот боязнить долгом она:
#    Но то бы на страстей уголк.
#    На поэта молчаливаю…
#    В подали со волнованьем,
#    И было наше страстей нас,
#    И вот в ней сердце под ней,
#    И вот ни как небо не водь.
# Loss: 1.337980191707611
#   Потом уж нет на страстью пора
#    И с первый слез и веселый,
#    И такого привычный друг,
#    У нас совершенственных добрый,
#    И думал уж на грустноном
#    И так не в сон сердце светло
#    Не отдала со в
# Loss: 1.3400771188735963
#   Приятный собой вольнаший страсти
#    И дам он обновляет от
#    И тем и пред нею сердца вас
#    В корпатьяны в старой ленивый
#    И подал и слезы лета,
#    В сем и страстей не страсти моя
#    И сумасбродо в
# Loss: 1.3307576632499696
#   И на после в грустно простой.
#
#
#
#  XXXIII
#
#    И всё в первый своей умиленье,
#    И в гостиных образ она.
#    Но в картины с нею с нею день,
#    На старинных души моей
#    Он прозор обозок молодой
#    С
# Loss: 1.3357571840286255
#   Подобный страсти молчалив,
#    И славы и под сердце свете,
#    Старушка с собою мертвой,
#    В семье страха, порой веле,
#    И после в сад сада подобный
#    И полно ты верно простой,
#    И городной старинн
# Loss: 1.3357368063926698
#   Что на сон страдали страсти,
#    И молчать он уж на страстей
#    Стоял он в как не подругой,
#    И вот на старинных страстей,
#    И славы с первые модной
#    Сторожно в ней на страшно в ней,
#    И славы с
# Loss: 1.3394054436683656
#   Под ним по сердце своей старины,
#    И старинных простите сельской
#    Отворотив света приводит
#    С как не старинные томный,
#    И с ней сердце постеле нет.
#    Татьяна под дослова голой.
#    Он после в
# Loss: 1.3305013918876647
#   Привез без подруга соседам
#    И в нем и слез был посланный,
#    На слез и в сердце не звоней
#    И в пестрый разговор и ветельной
#    Привычка после возврата,
#    В девицы сладкой полуденный,
#    В пора с
# Loss: 1.3285662174224853
#   Привычка с отразный должны,
#    Он спеси моей страстей мне,
#    И просто не последний строй
#    В сем он перевести столов
#    В рука полно полно одна
#    И не в семье простой пора
#    В нем отдалась он пер
# Loss: 1.3258698987960815
#   Старой подруга поле странной
#    В поле старинные старин,
#    И в том на супругом страстей,
#    И слышит не после в ней него
#    Прости в гостиным своей давно,
#    С ответ и все простите моей
#    В первый
# Loss: 1.3234424924850463
#   Вот стал в сени страсть вас не видеть,
#    В нем оставил он страшно нет!
#    Как в нем отворят старины;
#    Он верен он молодой вод.
#
#
#
#  XXXVII
#
#    Старинный ведьма постели
#    И после в собою зарон,
# Loss: 1.3185438013076782
#   Прости не предмете мой,
#    И всё простой и не забыла
#    Представит на старинный снег,
#    И с ней не славы на старин,
#    Глядит на старинной сон?..
#    «Не в собой старинный томный,
#    И безумный дом у
# Loss: 1.3197466135025024
#
# Loss: 1.322666711807251
#   Старинный мезловать она
#    В сем сладось не поле страницы
#    Перед ней ней ней души моле,
#    И он он мой подруга след,
#    Не полестный мой друг страсти
#    На старинных души мой,
#    Он отворят соверше
# Loss: 1.3175899124145507
#   Как верный друг и молчалива,
#    Как в песни в моей на старины
#    Стоял надежды после нет.
#    Всегда старинных сердце света
#    Не полный приятно за сердет,
#    И ум и послушной страницы
#    Приладит на
# Loss: 1.3187192630767823
#   Принежный сердца своей странно
#    Он подруги не старине,
#    И всё на светит в то в ней нет.
#    Прости в как наслаждала споры
#    И в сельский по неги не в сосед
#    И молчаливом свободы,
#    Так в семье
# Loss: 1.3153150010108947
#   В отворилась мой беленый суль
#    Старинной страсть верно должны
#    И всех подруги страстей мило
#    С он сердце молодой души,
#    И сумадался в ним со время
#    Перед не видеть он старины
#    В нем не ве
# Loss: 1.3067346692085267
#   Поспоре без последней сон полей
#    И в семейства сердце ей мой
#    В сем и старый добрый собою
#    Привыкнув сердце своей знать
#    В сем и странным свои поле,
#    И наш не страсти своей судьбой,
#    В се
# Loss: 1.3057502102851868
#   Он сердца своего света,
#    Под ней отворял своей ветель
#    Прости на своего страстей
#    Старинный встали в садится,
#    Он полукругой своей желанья,
#    И от ней соседей встали
#    Под сосед и привычный
# Loss: 1.3095009446144104
#   Он сердце своего подруга
#    Не всех предвав наслаждает;
#    Он по трудно нашел сердца слез
#    На старый взгляд мой душой.
#
#
#
#  XXXVI
#
#    Но всё был повесть не волной
#    С ней на трепетный природа
#
# Loss: 1.3092459750175476
#   В то ж и пред ней страстей мой,
#    И сердцем простили в семьей
#    Над там соседственно темно,
#    И подобен обедывал
#    По страшно преданьям слезы,
#    Постеле тем вечер обедом,
#    В одно не верно тем
# Loss: 1.3017871260643006
#   И встречно разлюблю в своим небрежной,
#    И думал с ней на старины,
#    И в нем домашни на света,
#    По нельзя с отворила смешной
#    В постеле на старинный лас
#    И страшный друг и слез без ней.
#
#
#
# Loss: 1.304913682937622
#   При восторгали в своей понимать
#    И мертвый своего поэта
#    Старины не видеть не высоки
#    И постепенней старый сам
#    И был не улыбнул слова,
#    Когда б возбужда своего,
#    И в колено слез был свое
# Loss: 1.301802625656128
#   Как только в своим на своей
#    С полна с ней он оставил он
#    И сердце голос оставила,
#    И встал в первый стол наконец
#    И сердце не своей страстей,
#    И в самом старины романа
#    Приятно в ней наш
# Loss: 1.2987933850288391
#   И славы, то после в ней страсть
#    С ней он подремленный бессела!
#    Но вас отворял со воле;
#    Татьяна всех родной поэта,
#    Онегин в картине простите,
#    Когда страстей мой постеле
#    И вот с ним о
# Loss: 1.3000471186637879
#   Поставил он после старинный, видеть.
#    Простопорок подал безумный,
#    И взор и после верную слез
#    И не страшной старинных дев,
#    Старинный простой соседовь;
#    Не после вольность его не друг.
#
#
# Loss: 1.297074785232544
#   Приходит она в ней она.
#
#
#
#  XXXIII
#
#    Прости с первые полей,
#    И пора страшно странным след.
#
#
#
#  XXIV
#
#    И в сказал он в перевестью
#    И в нем ожидает она,
#    И в семье смел на старины.
#
# Loss: 1.2883891296386718
#   Нет и слез и споров и странной
#    Привычка своевольно так
#    Простите мне вас обратить,
#    Молящий и в семьей старинный,
#    И подобла не страшно нет.
#    Но вот она с ней подобен.
#    В нем не под стол
# Loss: 1.29222327709198
#   Как самом на стол и страсть,
#    И славился в поле скалас.
#    Как постеле на своей девиц,
#    И старом сосед отрадой,
#    Да полно и страшный подруг,
#    На столь как полуденный стекло
#    Подал с ней на
# Loss: 1.296097764968872
#   Он отворила в тень она в ней, не видеть
#    Он с потом и в семьей того,
#    Что со страшно всё в нем и в ней.
#
#
#
#  XIII
#
#    Вот полно темно и странным след
#    Блаженство б не видит она,
#    Когда ж о
# Loss: 1.2901906275749206
#   В когда б в семье не встретилась,
#    Как торжественные луга.
#    Но в нем из первый подруга,
#    И в нем и после в ней она.
#    Он верно не простоты стала,
#    И в ней и темный приводит,
#    И думал он по
# Loss: 1.2949204897880555
#   И вот по наш предмет и страсти
#    И славы и думать поспете,
#    Что нам по только в ней на слов
#    И простоты сам надежда,
#    И темно не постеле в ней,
#    Под ней не видит она межде,
#    И вот в поле н
# Loss: 1.2903876900672913
#   В себе в самом он послушной, —
#    С ней соседей в семье забыла,
#    Как вашей вдохновенья, странный,
#    И сердце поражен она
#    В сем и страстный мечтанья страсти
#    С том на полетел на воленья,
#    И
# Loss: 1.2825422382354736
#   Он одно сердце постали высоков,
#    Не все привез по не верной
#    Старик от ней него светла,
#    Не все привлекательный взор
#    И ветреный постели в соседа,
#    На старый день о веселой,
#    Не правда ль
# Loss: 1.2792533874511718
#   И старый приветы в сердце в ней
#    Страшный стол бы его поэта,
#    И в то встреча не под небрежно,
#    И полный наш пора нас пора
#    И полный медведь конять нет.
#
#
#
#  XXXIII
#
#
#
#  XLVII
#
#    Но стра

# %%
model.eval()

print(evaluate(
    model, 
    char_to_idx, 
    idx_to_char, 
    temp=0.3, 
    prediction_len=1000, 
    start_text='.'
    )
)
# Out:
# .
#    Старик одной не свой поэта,
#    Которой постеле нас него
#    С ней девочки с первый верной
#    В потом и пора на последней,
#    И девы молодой души,
#    В приятный толковой воскресенье
#    И в семьей полукруг верный,
#    И сердце своего знал
#    В сумрак не всё был поэта,
#    Онегин в письмо правда ли?),
#    В постеле в сердце не преданья,
#    Не полу забыть молчать слышали,
#    Не под толковать поэта страстей
#    И совет и не верный себе
#    Не видит на старины нет.
#    Он волненье не приветы,
#    И встретились вот она всем,
#    С ней судьбу старой верной вольных,
#    Обеды молодой волшебный
#    Под сон уж нет соседи привычной,
#    И подруг не верно пора,
#    Под старый постеле свой пете
#    С какой первый приветы света
#    С полный на пред ним и приводит
#    Страшно не наших друг с пете,
#    Не предо не верно не свет
#    И кровь верный друг содревий,
#    Не под ним она с ней поэта,
#    С ней постеле на полку свой,
#    Не преданья в семьей раздела
#    И полно не полно простой,
#    В семьей под ним и кончалась,

# %%
model.eval()

print(evaluate(
    model, 
    char_to_idx, 
    idx_to_char, 
    temp=0.3, 
    prediction_len=256, 
    start_text='Татьяна'
    )
)
# Out:
# Татьяна сладо страстей ума
#    Простите с ней нет уста нет
#    И с ней обедом приводит,
#    В обращаясь он не знал
#    Простите мне с ней порой страданье
#    И тайны так в первый старин,
#    Но полный мой все для всех доле
#    И в семьей развел ведали
#    И с нею подость
